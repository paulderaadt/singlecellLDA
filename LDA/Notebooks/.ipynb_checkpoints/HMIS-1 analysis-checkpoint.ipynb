# %% [markdown]
# Data exploration of CyTOF sets

# %%
import pandas as pd

# %%
BMMC = pd.read_csv("../Data/BMMC_benchmark.csv")
AML
# Out:
#                Time  Cell_length         DNA1         DNA2     CD45RA  \
# 0         2693.0000         22.0   201.783295   253.016647   0.817049
# 1         3736.0000         35.0   191.828598   308.869080   3.801385
# 2         7015.0000         32.0   116.111923   200.839218   3.204439
# 3         7099.0000         29.0   176.248505   313.022461   2.237382
# 4         7700.0000         25.0   133.332779   226.467758  -0.044047
# 5         8333.0000         28.0   132.128220   326.021729   1.150336
# 6         8981.0000         23.0   201.681229   412.799896   4.726106
# 7         9363.0000         24.0   160.175644   319.568726   0.262788
# 8         9499.0000         25.0   205.975937   353.366058  -0.183864
# 9         9679.0000         26.0   114.608147   242.878723   0.557236
# 10       10801.0000         22.0   208.608765   326.687286   7.930744
# 11       11061.0000         31.0   158.533447   374.636932   3.846318
# ...

# %%
list(BMMC.columns)
# Out:
# ['CD45',
#  'CD45RA',
#  'CD19',
#  'CD11b',
#  'CD4',
#  'CD8',
#  'CD34',
#  'CD20',
#  'CD33',
#  'CD123',
#  'CD38',
#  'CD90',
#  'CD3',
#  'cell_type']
